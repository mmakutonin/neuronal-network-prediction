# %%
import os
import pickle
from sklearn.decomposition import PCA
from datetime import datetime

# %%
data_dir = '../data/'
input_data_dir = data_dir + 'data_raw_pickled/'
output_data_dir = data_dir + 'pca_models_pickled/'

# %%
timeseries_files = list(filter(lambda path: '_CellRespZ.pickle' in path if True else False,
       os.listdir(path = input_data_dir)))

# %%
def open_file(subject_number, file_path):
    with open(input_data_dir + file_path, "rb") as input_file:
        return pickle.load(input_file)

# %%
def create_model(n_components, data):
    pca_model = PCA(n_components=n_components, random_state=10)
    print('Beginning fit: ',datetime.now().time())
    pca_model.fit(data)
    print('Fitted: ',datetime.now().time())
    print('Variance Explained: ', pca_model.explained_variance_ratio_.sum())
    return pca_model

# %%
def pickle_model(model, subject_number, n_components):
    with open(output_data_dir + subject_number + '_PCA_model_num_comp_' + str(n_components) + '.pickle', 'wb') as pickle_file:
        pickle.dump(model, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def create_transformed_model(model, data, n_components, subject_number):
    model = model.transform(data)
    print('Transformed Model:', model.shape)
    pickle_model(model, subject_number, str(n_components) + '_transformed')

# %%
def create_pickled_models(n_components):
    for file in timeseries_files:
        subject_number = file.split('_')[1]
        print('Beginning fir for Subject #', str(subject_number))
        data = open_file(subject_number, file)
        model = create_model(n_components, data)
        pickle_model(model, subject_number, n_components)
        create_transformed_model(model, data, n_components, subject_number)

# %%
n_component_array = [10, 100, 1000]
for n_components in n_component_array:
    create_pickled_models(n_components)
# Out:
# Beginning fir for Subject # 10
# Beginning fit:  22:47:23.826046
# Fitted:  22:47:49.384556
# Variance Explained:  0.2277375963375185
# Transformed Model: (4426, 10)
# Beginning fir for Subject # 12
# Beginning fit:  22:48:01.569498
# Fitted:  22:48:27.654442
# Variance Explained:  0.29150793660767554
# Transformed Model: (6140, 10)
# Beginning fir for Subject # 13
# Beginning fit:  22:48:40.019275
# Fitted:  22:49:09.334201
# Variance Explained:  0.2344603348663612
# Transformed Model: (4840, 10)
# Beginning fir for Subject # 14
# Beginning fit:  22:49:20.372330
# Fitted:  22:49:40.561172
# Variance Explained:  0.30105228460484584
# Transformed Model: (3890, 10)
# Beginning fir for Subject # 15
# Beginning fit:  22:49:49.943850
# Fitted:  22:50:08.359421
# Variance Explained:  0.25467824050607457
# Transformed Model: (4880, 10)
# Beginning fir for Subject # 16
# Beginning fit:  22:50:14.471100
# Fitted:  22:50:23.549144
# Variance Explained:  0.262249766952139
# Transformed Model: (1877, 10)
# Beginning fir for Subject # 17
# Beginning fit:  22:50:31.294366
# Fitted:  22:50:56.597152
# Variance Explained:  0.16618997905277405
# Transformed Model: (5554, 10)
# Beginning fir for Subject # 1
# Beginning fit:  22:51:06.746678
# Fitted:  22:51:24.007523
# Variance Explained:  0.27116652523417545
# Transformed Model: (2880, 10)
# Beginning fir for Subject # 2
# Beginning fit:  22:51:32.793730
# Fitted:  22:51:53.909752
# Variance Explained:  0.1691626058295621
# Transformed Model: (3520, 10)
# Beginning fir for Subject # 3
# Beginning fit:  22:52:03.875120
# Fitted:  22:52:26.294848
# Variance Explained:  0.12483116156942413
# Transformed Model: (2560, 10)
# Beginning fir for Subject # 4
# Beginning fit:  22:52:35.714408
# Fitted:  22:52:56.049735
# Variance Explained:  0.11535373257986864
# Transformed Model: (2880, 10)
# Beginning fir for Subject # 5
# Beginning fit:  22:53:04.868824
# Fitted:  22:53:24.967674
# Variance Explained:  0.1786630171992071
# Transformed Model: (2880, 10)
# Beginning fir for Subject # 6
# Beginning fit:  22:53:35.814380
# Fitted:  22:54:01.371487
# Variance Explained:  0.1563520734061905
# Transformed Model: (3780, 10)
# Beginning fir for Subject # 7
# Beginning fit:  22:54:10.016139
# Fitted:  22:54:22.133773
# Variance Explained:  0.2849411999204738
# Transformed Model: (1650, 10)
# Beginning fir for Subject # 10
# Beginning fit:  22:54:30.599942
# Fitted:  22:55:51.463693
# Variance Explained:  0.4260725010860676
# Transformed Model: (4426, 100)
# Beginning fir for Subject # 12
# Beginning fit:  22:56:08.293204
# Fitted:  22:57:16.565525
# Variance Explained:  0.46393225256258863
# Transformed Model: (6140, 100)
# Beginning fir for Subject # 13
# Beginning fit:  22:57:31.384561
# Fitted:  22:58:36.353144
# Variance Explained:  0.3930588847048949
# Transformed Model: (4840, 100)
# Beginning fir for Subject # 14
# Beginning fit:  22:58:48.313037
# Fitted:  22:59:41.218682
# Variance Explained:  0.4460924990472328
# Transformed Model: (3890, 100)
# Beginning fir for Subject # 15
# Beginning fit:  22:59:52.238193
# Fitted:  23:00:37.563390
# Variance Explained:  0.4121655262138867
# Transformed Model: (4880, 100)
# Beginning fir for Subject # 16
# Beginning fit:  23:00:45.691240
# Fitted:  23:01:08.888123
# Variance Explained:  0.46744611872697023
# Transformed Model: (1877, 100)
# Beginning fir for Subject # 17
# Beginning fit:  23:01:17.050542
# Fitted:  23:02:22.645969
# Variance Explained:  0.3051289232486891
# Transformed Model: (5554, 100)
# Beginning fir for Subject # 1
# Beginning fit:  23:02:34.578847
# Fitted:  23:03:20.498319
# Variance Explained:  0.45173969082874943
# Transformed Model: (2880, 100)
# Beginning fir for Subject # 2
# Beginning fit:  23:03:32.544008
# Fitted:  23:04:28.038598
# Variance Explained:  0.33853878147223626
# Transformed Model: (3520, 100)
# Beginning fir for Subject # 3
# Beginning fit:  23:04:38.458462
# Fitted:  23:05:18.723312
# Variance Explained:  0.31342208174088526
# Transformed Model: (2560, 100)
# Beginning fir for Subject # 4
# Beginning fit:  23:05:29.665413
# Fitted:  23:06:21.738380
# Variance Explained:  0.2485370423212322
# Transformed Model: (2880, 100)
# Beginning fir for Subject # 5
# Beginning fit:  23:06:34.876886
# Fitted:  23:07:29.478470
# Variance Explained:  0.3499221548667612
# Transformed Model: (2880, 100)
# Beginning fir for Subject # 6
# Beginning fit:  23:07:42.055590
# Fitted:  23:08:47.631316
# Variance Explained:  0.31918419445093527
# Transformed Model: (3780, 100)
# Beginning fir for Subject # 7
# Beginning fit:  23:08:59.197653
# Fitted:  23:09:30.577164
# Variance Explained:  0.45926303004556795
# Transformed Model: (1650, 100)
# Beginning fir for Subject # 10
# Beginning fit:  23:09:40.256523
# Fitted:  23:15:27.323188
# Variance Explained:  0.6558741695520415
# Transformed Model: (4426, 1000)
# Beginning fir for Subject # 12
# Beginning fit:  23:16:14.437125
# Fitted:  23:21:16.769821
# Variance Explained:  0.6636778312952105
# Transformed Model: (6140, 1000)
# Beginning fir for Subject # 13
# Beginning fit:  23:21:59.619029
# Fitted:  23:28:57.040419
# Variance Explained:  0.5932504140869077
# Transformed Model: (4840, 1000)
# Beginning fir for Subject # 14
# Beginning fit:  23:29:45.506716
# Fitted:  23:34:39.143062
# Variance Explained:  0.6531346893533065
# Transformed Model: (3890, 1000)
# Beginning fir for Subject # 15
# Beginning fit:  23:35:14.061433
# Fitted:  23:39:03.719280
# Variance Explained:  0.6335277443464239
# Transformed Model: (4880, 1000)
# Beginning fir for Subject # 16
# Beginning fit:  23:39:33.442315
# Fitted:  23:41:48.158886
# Variance Explained:  0.7915249818060885
# Transformed Model: (1877, 1000)
# Beginning fir for Subject # 17
# Beginning fit:  23:42:09.608259
# Fitted:  23:45:49.289962
# Variance Explained:  0.5332468151413176
# Transformed Model: (5554, 1000)
# Beginning fir for Subject # 1
# Beginning fit:  23:46:15.089583
# Fitted:  23:48:56.724687
# Variance Explained:  0.709599878337567
# Transformed Model: (2880, 1000)
# Beginning fir for Subject # 2
# Beginning fit:  23:49:18.508259
# Fitted:  23:52:24.926225
# Variance Explained:  0.615904744213168
# Transformed Model: (3520, 1000)
# Beginning fir for Subject # 3
# Beginning fit:  23:52:50.678969
# Fitted:  23:55:21.730377
# Variance Explained:  0.6428190170700323
# Transformed Model: (2560, 1000)
# Beginning fir for Subject # 4
# Beginning fit:  23:55:43.232674
# Fitted:  23:58:33.391407
# Variance Explained:  0.559447912226865
# Transformed Model: (2880, 1000)
# Beginning fir for Subject # 5
# Beginning fit:  23:58:57.647709
# Fitted:  00:02:06.810629
# Variance Explained:  0.6281929510793339
# Transformed Model: (2880, 1000)
# Beginning fir for Subject # 6
# Beginning fit:  00:02:32.813403
# Fitted:  00:06:08.792466
# Variance Explained:  0.5718185235262591
# Transformed Model: (3780, 1000)
# Beginning fir for Subject # 7
# Beginning fit:  00:06:36.139133
# Fitted:  00:08:42.030530
# Variance Explained:  0.8050293576572185
# Transformed Model: (1650, 1000)

# %%
print(timeseries_files)
