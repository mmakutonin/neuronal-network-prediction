# %%
import os
import pickle
from sklearn.decomposition import PCA
from datetime import datetime

# %%
data_dir = '../data/'
input_data_dir = data_dir + 'data_raw_pickled/'
output_data_dir = data_dir + 'pca_models_pickled/'

# %%
timeseries_files = list(filter(lambda path: '_CellRespZ.pickle' in path if True else False,
       os.listdir(path = input_data_dir)))

# %%
def open_file(file_path):
    with open(input_data_dir + file_path, "rb") as input_file:
        return pickle.load(input_file)

# %%
def create_model(n_components, data):
    pca_model = PCA(n_components=n_components, random_state=10)
    print('Beginning fit: ',datetime.now().time())
    pca_model.fit(data)
    print('Fitted: ',datetime.now().time())
    print('Variance Explained: ', pca_model.explained_variance_ratio_.sum())
    return pca_model

# %%
def pickle_model(model, data_label, n_components):
    with open(output_data_dir + data_label + '_PCA_model_num_comp_' + str(n_components) + '.pickle', 'wb') as pickle_file:
        pickle.dump(model, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def create_transformed_model(model, data, n_components, data_label):
    model = model.transform(data)
    print('Transformed Model:', model.shape)
    pickle_model(model, data_label, str(n_components) + '_transformed')

# %%
def create_pickled_models(n_components):
    for file in timeseries_files:
        data_label = file.split('_CellRespZ')[0]
        print('Beginning fit for', str(data_label))
        data = open_file(file)
        n_components = min(min(data.shape), n_components)
        model = create_model(n_components, data)
        pickle_model(model, data_label, n_components)
        create_transformed_model(model, data, n_components, data_label)

# %%
n_component_array = [10, 100]
for n_components in n_component_array:
    create_pickled_models(n_components)
# Out:
# Beginning fit for subject_10
# Beginning fit:  18:57:20.904807
# Fitted:  18:57:47.322654
# Variance Explained:  0.2277375963375185
# Transformed Model: (4426, 10)
# Beginning fit for subject_10_stimulus_0
# Beginning fit:  18:57:54.656683
# Fitted:  18:57:55.605206
# Variance Explained:  0.28340653
# Transformed Model: (204, 10)
# Beginning fit for subject_10_stimulus_10
# Beginning fit:  18:57:56.037857
# Fitted:  18:57:56.761782
# Variance Explained:  0.48495638
# Transformed Model: (220, 10)
# Beginning fit for subject_10_stimulus_11
# Beginning fit:  18:57:57.199384
# Fitted:  18:57:57.947874
# Variance Explained:  0.39229643
# Transformed Model: (220, 10)
# Beginning fit for subject_10_stimulus_12
# Beginning fit:  18:57:58.438680
# Fitted:  18:57:59.946189
# Variance Explained:  0.31091976
# Transformed Model: (220, 10)
# Beginning fit for subject_10_stimulus_13
# Beginning fit:  18:58:00.528738
# Fitted:  18:58:01.479766
# Variance Explained:  0.30149522
# Transformed Model: (202, 10)
# Beginning fit for subject_10_stimulus_14
# Beginning fit:  18:58:01.693333
# Fitted:  18:58:01.949516
# Variance Explained:  0.7094455
# Transformed Model: (40, 10)
# Beginning fit for subject_10_stimulus_15
# Beginning fit:  18:58:02.088384
# Fitted:  18:58:02.341057
# Variance Explained:  0.67512584
# Transformed Model: (40, 10)
# Beginning fit for subject_10_stimulus_16
# Beginning fit:  18:58:02.482432
# Fitted:  18:58:02.759168
# Variance Explained:  0.5059449
# Transformed Model: (50, 10)
# Beginning fit for subject_10_stimulus_1
# Beginning fit:  18:58:03.184613
# Fitted:  18:58:04.098541
# Variance Explained:  0.2740444
# Transformed Model: (300, 10)
# Beginning fit for subject_10_stimulus_21
# Beginning fit:  18:58:04.477049
# Fitted:  18:58:05.056597
# Variance Explained:  0.3766163
# Transformed Model: (150, 10)
# Beginning fit for subject_10_stimulus_22
# Beginning fit:  18:58:05.382964
# Fitted:  18:58:06.149503
# Variance Explained:  0.36303562
# Transformed Model: (150, 10)
# Beginning fit for subject_10_stimulus_23
# Beginning fit:  18:58:06.648831
# Fitted:  18:58:07.924223
# Variance Explained:  0.30497307
# Transformed Model: (200, 10)
# Beginning fit for subject_10_stimulus_2
# Beginning fit:  18:58:08.529332
# Fitted:  18:58:09.362546
# Variance Explained:  0.3151551
# Transformed Model: (300, 10)
# Beginning fit for subject_10_stimulus_3
# Beginning fit:  18:58:10.471300
# Fitted:  18:58:12.274465
# Variance Explained:  0.35062274
# Transformed Model: (780, 10)
# Beginning fit for subject_10_stimulus_4
# Beginning fit:  18:58:13.617036
# Fitted:  18:58:16.295158
# Variance Explained:  0.28223556
# Transformed Model: (720, 10)
# Beginning fit for subject_10_stimulus_9
# Beginning fit:  18:58:17.439202
# Fitted:  18:58:18.849450
# Variance Explained:  0.28221548
# Transformed Model: (630, 10)
# Beginning fit for subject_12
# Beginning fit:  18:58:24.097523
# Fitted:  18:58:42.546587
# Variance Explained:  0.29150793660767554
# Transformed Model: (6140, 10)
# Beginning fit for subject_12_stimulus_0
# Beginning fit:  18:58:47.926394
# Fitted:  18:58:48.905998
# Variance Explained:  0.4068365
# Transformed Model: (500, 10)
# Beginning fit for subject_12_stimulus_10
# Beginning fit:  18:58:49.261944
# Fitted:  18:58:49.679054
# Variance Explained:  0.41557926
# Transformed Model: (150, 10)
# Beginning fit for subject_12_stimulus_11
# Beginning fit:  18:58:49.921199
# Fitted:  18:58:50.547363
# Variance Explained:  0.49005276
# Transformed Model: (150, 10)
# Beginning fit for subject_12_stimulus_12
# Beginning fit:  18:58:50.831619
# Fitted:  18:58:51.418680
# Variance Explained:  0.49337786
# Transformed Model: (150, 10)
# Beginning fit for subject_12_stimulus_14
# Beginning fit:  18:58:51.578104
# Fitted:  18:58:51.813731
# Variance Explained:  0.83203775
# Transformed Model: (25, 10)
# Beginning fit for subject_12_stimulus_15
# Beginning fit:  18:58:51.894947
# Fitted:  18:58:52.062391
# Variance Explained:  0.83971035
# Transformed Model: (25, 10)
# Beginning fit for subject_12_stimulus_1
# Beginning fit:  18:58:52.740813
# Fitted:  18:58:53.916438
# Variance Explained:  0.24923545
# Transformed Model: (800, 10)
# Beginning fit for subject_12_stimulus_2
# Beginning fit:  18:58:54.977761
# Fitted:  18:58:56.178954
# Variance Explained:  0.35040292
# Transformed Model: (800, 10)
# Beginning fit for subject_12_stimulus_3
# Beginning fit:  18:58:58.794960
# Fitted:  18:59:03.135001
# Variance Explained:  0.28046867
# Transformed Model: (2750, 10)
# Beginning fit for subject_12_stimulus_4
# Beginning fit:  18:59:04.798424
# Fitted:  18:59:05.966530
# Variance Explained:  0.29088715
# Transformed Model: (640, 10)
# Beginning fit for subject_12_stimulus_9
# Beginning fit:  18:59:06.356066
# Fitted:  18:59:06.748108
# Variance Explained:  0.3922849
# Transformed Model: (150, 10)
# Beginning fit for subject_13
# Beginning fit:  18:59:12.306368
# Fitted:  18:59:30.039897
# Variance Explained:  0.2344603348663612
# Transformed Model: (4840, 10)
# Beginning fit for subject_13_stimulus_0
# Beginning fit:  18:59:34.973517
# Fitted:  18:59:35.764621
# Variance Explained:  0.35165262
# Transformed Model: (270, 10)
# Beginning fit for subject_13_stimulus_10
# Beginning fit:  18:59:35.996737
# Fitted:  18:59:36.225346
# Variance Explained:  0.37716797
# Transformed Model: (50, 10)
# Beginning fit for subject_13_stimulus_11
# Beginning fit:  18:59:36.356194
# Fitted:  18:59:36.567756
# Variance Explained:  0.3810455
# Transformed Model: (50, 10)
# Beginning fit for subject_13_stimulus_12
# Beginning fit:  18:59:36.687073
# Fitted:  18:59:36.925207
# Variance Explained:  0.38007724
# Transformed Model: (50, 10)
# Beginning fit for subject_13_stimulus_14
# Beginning fit:  18:59:37.110199
# Fitted:  18:59:37.428546
# Variance Explained:  0.51512665
# Transformed Model: (100, 10)
# Beginning fit for subject_13_stimulus_15
# Beginning fit:  18:59:37.633089
# Fitted:  18:59:37.994550
# Variance Explained:  0.5823086
# Transformed Model: (100, 10)
# Beginning fit for subject_13_stimulus_1
# Beginning fit:  18:59:38.524374
# Fitted:  18:59:39.869450
# Variance Explained:  0.24144152
# Transformed Model: (440, 10)
# Beginning fit for subject_13_stimulus_2
# Beginning fit:  18:59:40.814966
# Fitted:  18:59:41.994100
# Variance Explained:  0.2714041
# Transformed Model: (440, 10)
# Beginning fit for subject_13_stimulus_3
# Beginning fit:  18:59:44.261016
# Fitted:  18:59:49.352055
# Variance Explained:  0.27898526
# Transformed Model: (2090, 10)
# Beginning fit for subject_13_stimulus_4
# Beginning fit:  18:59:51.685736
# Fitted:  18:59:54.043004
# Variance Explained:  0.1777181
# Transformed Model: (1200, 10)
# Beginning fit for subject_13_stimulus_9
# Beginning fit:  18:59:55.002555
# Fitted:  18:59:55.588112
# Variance Explained:  0.37852404
# Transformed Model: (50, 10)
# Beginning fit for subject_14
# Beginning fit:  18:59:59.623003
# Fitted:  19:00:14.513190
# Variance Explained:  0.30105228460484584
# Transformed Model: (3890, 10)
# Beginning fit for subject_14_stimulus_0
# Beginning fit:  19:00:18.290815
# Fitted:  19:00:19.025267
# Variance Explained:  0.53431183
# Transformed Model: (175, 10)
# Beginning fit for subject_14_stimulus_10
# Beginning fit:  19:00:19.200233
# Fitted:  19:00:19.415807
# Variance Explained:  0.68703634
# Transformed Model: (30, 10)
# Beginning fit for subject_14_stimulus_11
# Beginning fit:  19:00:19.516574
# Fitted:  19:00:19.725630
# Variance Explained:  0.52471685
# Transformed Model: (30, 10)
# Beginning fit for subject_14_stimulus_12
# Beginning fit:  19:00:19.821385
# Fitted:  19:00:20.032948
# Variance Explained:  0.51705086
# Transformed Model: (30, 10)
# Beginning fit for subject_14_stimulus_14
# Beginning fit:  19:00:20.140734
# Fitted:  19:00:20.371347
# Variance Explained:  0.7360916
# Transformed Model: (40, 10)
# Beginning fit for subject_14_stimulus_15
# Beginning fit:  19:00:20.482643
# Fitted:  19:00:20.710749
# Variance Explained:  0.78204
# Transformed Model: (40, 10)
# Beginning fit for subject_14_stimulus_1
# Beginning fit:  19:00:21.406061
# Fitted:  19:00:22.603668
# Variance Explained:  0.21775101
# Transformed Model: (640, 10)
# Beginning fit for subject_14_stimulus_2
# Beginning fit:  19:00:23.724920
# Fitted:  19:00:26.088203
# Variance Explained:  0.14407562
# Transformed Model: (640, 10)
# Beginning fit for subject_14_stimulus_3
# Beginning fit:  19:00:28.161581
# Fitted:  19:00:31.106971
# Variance Explained:  0.33140373
# Transformed Model: (1735, 10)
# Beginning fit for subject_14_stimulus_4
# Beginning fit:  19:00:32.871162
# Fitted:  19:00:34.019715
# Variance Explained:  0.38568932
# Transformed Model: (500, 10)
# Beginning fit for subject_14_stimulus_9
# Beginning fit:  19:00:34.315502
# Fitted:  19:00:34.516537
# Variance Explained:  0.5319177
# Transformed Model: (30, 10)
# Beginning fit for subject_15
# Beginning fit:  19:00:38.200276
# Fitted:  19:00:51.713218
# Variance Explained:  0.25467824050607457
# Transformed Model: (4880, 10)
# Beginning fit for subject_15_stimulus_0
# Beginning fit:  19:00:55.636148
# Fitted:  19:00:56.232735
# Variance Explained:  0.25388137
# Transformed Model: (330, 10)
# Beginning fit for subject_15_stimulus_10
# Beginning fit:  19:00:56.594196
# Fitted:  19:00:57.018324
# Variance Explained:  0.5363014
# Transformed Model: (240, 10)
# Beginning fit for subject_15_stimulus_11
# Beginning fit:  19:00:57.307091
# Fitted:  19:00:57.751273
# Variance Explained:  0.2690565
# Transformed Model: (240, 10)
# Beginning fit for subject_15_stimulus_12
# Beginning fit:  19:00:58.040041
# Fitted:  19:00:58.482722
# Variance Explained:  0.24152443
# Transformed Model: (240, 10)
# Beginning fit for subject_15_stimulus_14
# Beginning fit:  19:00:58.650666
# Fitted:  19:00:58.816607
# Variance Explained:  0.57656795
# Transformed Model: (50, 10)
# Beginning fit for subject_15_stimulus_15
# Beginning fit:  19:00:58.920883
# Fitted:  19:00:59.092341
# Variance Explained:  0.5913882
# Transformed Model: (50, 10)
# Beginning fit for subject_15_stimulus_1
# Beginning fit:  19:00:59.674473
# Fitted:  19:01:01.223594
# Variance Explained:  0.12140923
# Transformed Model: (725, 10)
# Beginning fit for subject_15_stimulus_2
# Beginning fit:  19:01:02.432809
# Fitted:  19:01:03.691155
# Variance Explained:  0.11119949
# Transformed Model: (725, 10)
# Beginning fit for subject_15_stimulus_3
# Beginning fit:  19:01:04.996313
# Fitted:  19:01:06.935468
# Variance Explained:  0.3229369
# Transformed Model: (1440, 10)
# Beginning fit for subject_15_stimulus_4
# Beginning fit:  19:01:07.929535
# Fitted:  19:01:09.699240
# Variance Explained:  0.42736787
# Transformed Model: (600, 10)
# Beginning fit for subject_15_stimulus_9
# Beginning fit:  19:01:10.285801
# Fitted:  19:01:10.840777
# Variance Explained:  0.334645
# Transformed Model: (240, 10)
# Beginning fit for subject_16
# Beginning fit:  19:01:12.584011
# Fitted:  19:01:19.283346
# Variance Explained:  0.262249766952139
# Transformed Model: (1877, 10)
# Beginning fit for subject_16_stimulus_10
# Beginning fit:  19:01:20.573276
# Fitted:  19:01:20.805896
# Variance Explained:  0.5352727
# Transformed Model: (80, 10)
# Beginning fit for subject_16_stimulus_11
# Beginning fit:  19:01:20.968828
# Fitted:  19:01:21.204464
# Variance Explained:  0.44878045
# Transformed Model: (80, 10)
# Beginning fit for subject_16_stimulus_12
# Beginning fit:  19:01:21.381936
# Fitted:  19:01:21.640623
# Variance Explained:  0.42467523
# Transformed Model: (80, 10)
# Beginning fit for subject_16_stimulus_1
# Beginning fit:  19:01:21.982550
# Fitted:  19:01:22.655841
# Variance Explained:  0.2308344
# Transformed Model: (300, 10)
# Beginning fit for subject_16_stimulus_2
# Beginning fit:  19:01:23.110522
# Fitted:  19:01:24.311215
# Variance Explained:  0.20389763
# Transformed Model: (300, 10)
# Beginning fit for subject_16_stimulus_3
# Beginning fit:  19:01:25.158468
# Fitted:  19:01:26.286969
# Variance Explained:  0.23809178
# Transformed Model: (440, 10)
# Beginning fit for subject_16_stimulus_4
# Beginning fit:  19:01:26.944462
# Fitted:  19:01:27.815308
# Variance Explained:  0.29481253
# Transformed Model: (517, 10)
# Beginning fit for subject_16_stimulus_9
# Beginning fit:  19:01:28.127139
# Fitted:  19:01:28.355745
# Variance Explained:  0.42492196
# Transformed Model: (80, 10)
# Beginning fit for subject_17
# Beginning fit:  19:01:33.659547
# Fitted:  19:01:51.007668
# Variance Explained:  0.16618997905277405
# Transformed Model: (5554, 10)
# Beginning fit for subject_17_stimulus_0
# Beginning fit:  19:01:58.070454
# Fitted:  19:01:59.076125
# Variance Explained:  0.2044802
# Transformed Model: (352, 10)
# Beginning fit for subject_17_stimulus_10
# Beginning fit:  19:01:59.462652
# Fitted:  19:02:00.059237
# Variance Explained:  0.43117088
# Transformed Model: (192, 10)
# Beginning fit for subject_17_stimulus_11
# Beginning fit:  19:02:00.377083
# Fitted:  19:02:00.995728
# Variance Explained:  0.26016808
# Transformed Model: (192, 10)
# Beginning fit for subject_17_stimulus_12
# Beginning fit:  19:02:01.369723
# Fitted:  19:02:01.964304
# Variance Explained:  0.26104814
# Transformed Model: (192, 10)
# Beginning fit for subject_17_stimulus_14
# Beginning fit:  19:02:02.142779
# Fitted:  19:02:02.361360
# Variance Explained:  0.50936025
# Transformed Model: (50, 10)
# Beginning fit for subject_17_stimulus_15
# Beginning fit:  19:02:02.482181
# Fitted:  19:02:02.716806
# Variance Explained:  0.49210542
# Transformed Model: (50, 10)
# Beginning fit for subject_17_stimulus_1
# Beginning fit:  19:02:03.585115
# Fitted:  19:02:05.995524
# Variance Explained:  0.117545985
# Transformed Model: (783, 10)
# Beginning fit for subject_17_stimulus_2
# Beginning fit:  19:02:07.098098
# Fitted:  19:02:08.646715
# Variance Explained:  0.145221
# Transformed Model: (783, 10)
# Beginning fit for subject_17_stimulus_3
# Beginning fit:  19:02:10.851206
# Fitted:  19:02:15.143620
# Variance Explained:  0.20572434
# Transformed Model: (1968, 10)
# Beginning fit for subject_17_stimulus_4
# Beginning fit:  19:02:16.645566
# Fitted:  19:02:17.906920
# Variance Explained:  0.18335387
# Transformed Model: (800, 10)
# Beginning fit for subject_17_stimulus_9
# Beginning fit:  19:02:18.482954
# Fitted:  19:02:19.521716
# Variance Explained:  0.25065896
# Transformed Model: (192, 10)
# Beginning fit for subject_1
# Beginning fit:  19:02:23.545172
# Fitted:  19:02:37.954488
# Variance Explained:  0.27116652523417545
# Transformed Model: (2880, 10)
# Beginning fit for subject_1_stimulus_0
# Beginning fit:  19:02:41.405847
# Fitted:  19:02:43.621238
# Variance Explained:  0.37939614
# Transformed Model: (720, 10)
# Beginning fit for subject_1_stimulus_1
# Beginning fit:  19:02:45.026545
# Fitted:  19:02:47.079003
# Variance Explained:  0.22169599
# Transformed Model: (720, 10)
# Beginning fit for subject_1_stimulus_2
# Beginning fit:  19:02:48.408045
# Fitted:  19:02:51.497762
# Variance Explained:  0.2908412
# Transformed Model: (720, 10)
# Beginning fit for subject_1_stimulus_3
# Beginning fit:  19:02:53.082475
# Fitted:  19:02:55.189076
# Variance Explained:  0.22213154
# Transformed Model: (720, 10)
# Beginning fit for subject_2
# Beginning fit:  19:03:00.890237
# Fitted:  19:03:18.984854
# Variance Explained:  0.1691626058295621
# Transformed Model: (3520, 10)
# Beginning fit for subject_2_stimulus_0
# Beginning fit:  19:03:24.953726
# Fitted:  19:03:27.474429
# Variance Explained:  0.17270887
# Transformed Model: (880, 10)
# Beginning fit for subject_2_stimulus_1
# Beginning fit:  19:03:29.106268
# Fitted:  19:03:32.384486
# Variance Explained:  0.16769333
# Transformed Model: (880, 10)
# Beginning fit for subject_2_stimulus_2
# Beginning fit:  19:03:34.157716
# Fitted:  19:03:36.569135
# Variance Explained:  0.13985135
# Transformed Model: (880, 10)
# Beginning fit for subject_2_stimulus_3
# Beginning fit:  19:03:38.345863
# Fitted:  19:03:41.911342
# Variance Explained:  0.22479843
# Transformed Model: (880, 10)
# Beginning fit for subject_3
# Beginning fit:  19:03:45.874379
# Fitted:  19:04:02.752262
# Variance Explained:  0.12483116156942413
# Transformed Model: (2560, 10)
# Beginning fit for subject_3_stimulus_0
# Beginning fit:  19:04:06.026969
# Fitted:  19:04:08.201250
# Variance Explained:  0.16255835
# Transformed Model: (640, 10)
# Beginning fit for subject_3_stimulus_1
# Beginning fit:  19:04:09.461101
# Fitted:  19:04:10.908949
# Variance Explained:  0.13851872
# Transformed Model: (640, 10)
# Beginning fit for subject_3_stimulus_2
# Beginning fit:  19:04:12.024082
# Fitted:  19:04:14.342749
# Variance Explained:  0.1329183
# Transformed Model: (640, 10)
# Beginning fit for subject_3_stimulus_3
# Beginning fit:  19:04:15.630673
# Fitted:  19:04:17.149241
# Variance Explained:  0.15894449
# Transformed Model: (640, 10)
# Beginning fit for subject_4
# Beginning fit:  19:04:21.463713
# Fitted:  19:04:35.615350
# Variance Explained:  0.11535373257986864
# Transformed Model: (2880, 10)
# Beginning fit for subject_4_stimulus_0
# Beginning fit:  19:04:39.975077
# Fitted:  19:04:41.846051
# Variance Explained:  0.124091096
# Transformed Model: (720, 10)
# Beginning fit for subject_4_stimulus_1
# Beginning fit:  19:04:43.728056
# Fitted:  19:04:45.738401
# Variance Explained:  0.10693052
# Transformed Model: (720, 10)
# Beginning fit for subject_4_stimulus_2
# Beginning fit:  19:04:47.036886
# Fitted:  19:04:49.319956
# Variance Explained:  0.11394937
# Transformed Model: (720, 10)
# Beginning fit for subject_4_stimulus_3
# Beginning fit:  19:04:51.199955
# Fitted:  19:04:53.570758
# Variance Explained:  0.13217765
# Transformed Model: (720, 10)
# Beginning fit for subject_5
# Beginning fit:  19:04:58.799998
# Fitted:  19:05:18.872556
# Variance Explained:  0.1786630171992071
# Transformed Model: (2880, 10)
# Beginning fit for subject_5_stimulus_0
# Beginning fit:  19:05:24.842147
# Fitted:  19:05:26.952259
# Variance Explained:  0.22013062
# Transformed Model: (720, 10)
# Beginning fit for subject_5_stimulus_1
# Beginning fit:  19:05:29.091448
# Fitted:  19:05:31.248684
# Variance Explained:  0.16767932
# Transformed Model: (720, 10)
# Beginning fit for subject_5_stimulus_2
# Beginning fit:  19:05:32.652667
# Fitted:  19:05:34.437414
# Variance Explained:  0.17475393
# Transformed Model: (720, 10)
# Beginning fit for subject_5_stimulus_3
# Beginning fit:  19:05:36.491877
# Fitted:  19:05:38.538333
# Variance Explained:  0.2103066
# Transformed Model: (720, 10)
# Beginning fit for subject_6
# Beginning fit:  19:05:44.542630
# Fitted:  19:06:02.581612
# Variance Explained:  0.1563520734061905
# Transformed Model: (3780, 10)
# Beginning fit for subject_6_stimulus_1
# Beginning fit:  19:06:08.608942
# Fitted:  19:06:11.221891
# Variance Explained:  0.16409197
# Transformed Model: (1080, 10)
# Beginning fit for subject_6_stimulus_2
# Beginning fit:  19:06:13.706499
# Fitted:  19:06:17.349185
# Variance Explained:  0.17377564
# Transformed Model: (1080, 10)
# Beginning fit for subject_6_stimulus_3
# Beginning fit:  19:06:20.030378
# Fitted:  19:06:25.115399
# Variance Explained:  0.12329955
# Transformed Model: (1620, 10)
# Beginning fit for subject_7
# Beginning fit:  19:06:28.105598
# Fitted:  19:06:36.160493
# Variance Explained:  0.2849411999204738
# Transformed Model: (1650, 10)
# Beginning fit for subject_7_stimulus_1
# Beginning fit:  19:06:39.550507
# Fitted:  19:06:40.973943
# Variance Explained:  0.31926614
# Transformed Model: (550, 10)
# Beginning fit for subject_7_stimulus_2
# Beginning fit:  19:06:42.006945
# Fitted:  19:06:43.383607
# Variance Explained:  0.30867872
# Transformed Model: (550, 10)
# Beginning fit for subject_7_stimulus_3
# Beginning fit:  19:06:44.600366
# Fitted:  19:06:46.916024
# Variance Explained:  0.284277
# Transformed Model: (550, 10)
# Beginning fit for subject_10
# Beginning fit:  19:06:52.707613
# Fitted:  19:07:39.185647
# Variance Explained:  0.4260725010860676
# Transformed Model: (4426, 100)
# Beginning fit for subject_10_stimulus_0
# Beginning fit:  19:07:45.522519
# Fitted:  19:07:47.667339
# Variance Explained:  0.6775731
# Transformed Model: (204, 100)
# Beginning fit for subject_10_stimulus_10
# Beginning fit:  19:07:48.352932
# Fitted:  19:07:51.763500
# Variance Explained:  0.7744038
# Transformed Model: (220, 100)
# Beginning fit for subject_10_stimulus_11
# Beginning fit:  19:07:52.458454
# Fitted:  19:07:54.475820
# Variance Explained:  0.72162366
# Transformed Model: (220, 100)
# Beginning fit for subject_10_stimulus_12
# Beginning fit:  19:07:55.128934
# Fitted:  19:07:58.224198
# Variance Explained:  0.6796481
# Transformed Model: (220, 100)
# Beginning fit for subject_10_stimulus_13
# Beginning fit:  19:07:59.070447
# Fitted:  19:08:01.071804
# Variance Explained:  0.69342077
# Transformed Model: (202, 100)
# Beginning fit for subject_10_stimulus_14
# Beginning fit:  19:08:01.588259
# Fitted:  19:08:01.750117
# Variance Explained:  0.99999994
# Transformed Model: (40, 40)
# Beginning fit for subject_10_stimulus_15
# Beginning fit:  19:08:01.862975
# Fitted:  19:08:02.022901
# Variance Explained:  0.99999994
# Transformed Model: (40, 40)
# Beginning fit for subject_10_stimulus_16
# Beginning fit:  19:08:02.156268
# Fitted:  19:08:02.364447
# Variance Explained:  0.92193735
# Transformed Model: (50, 40)
# Beginning fit for subject_10_stimulus_1
# Beginning fit:  19:08:02.860746
# Fitted:  19:08:04.714197
# Variance Explained:  0.44266135
# Transformed Model: (300, 40)
# Beginning fit for subject_10_stimulus_21
# Beginning fit:  19:08:05.539894
# Fitted:  19:08:06.861409
# Variance Explained:  0.5906267
# Transformed Model: (150, 40)
# Beginning fit for subject_10_stimulus_22
# Beginning fit:  19:08:07.238933
# Fitted:  19:08:08.084217
# Variance Explained:  0.59586143
# Transformed Model: (150, 40)
# Beginning fit for subject_10_stimulus_23
# Beginning fit:  19:08:08.519372
# Fitted:  19:08:09.434806
# Variance Explained:  0.50943506
# Transformed Model: (200, 40)
# Beginning fit for subject_10_stimulus_2
# Beginning fit:  19:08:09.975695
# Fitted:  19:08:11.125253
# Variance Explained:  0.48271343
# Transformed Model: (300, 40)
# Beginning fit for subject_10_stimulus_3
# Beginning fit:  19:08:13.107523
# Fitted:  19:08:16.172172
# Variance Explained:  0.5050646
# Transformed Model: (780, 40)
# Beginning fit for subject_10_stimulus_4
# Beginning fit:  19:08:17.697266
# Fitted:  19:08:24.031326
# Variance Explained:  0.4239905
# Transformed Model: (720, 40)
# Beginning fit for subject_10_stimulus_9
# Beginning fit:  19:08:25.298256
# Fitted:  19:08:28.022001
# Variance Explained:  0.44144362
# Transformed Model: (630, 40)
# Beginning fit for subject_12
# Beginning fit:  19:08:33.868216
# Fitted:  19:08:58.048110
# Variance Explained:  0.39134812942165875
# Transformed Model: (6140, 40)
# Beginning fit for subject_12_stimulus_0
# Beginning fit:  19:09:03.794390
# Fitted:  19:09:05.235730
# Variance Explained:  0.54824865
# Transformed Model: (500, 40)
# Beginning fit for subject_12_stimulus_10
# Beginning fit:  19:09:05.611730
# Fitted:  19:09:06.201799
# Variance Explained:  0.5937023
# Transformed Model: (150, 40)
# Beginning fit for subject_12_stimulus_11
# Beginning fit:  19:09:06.561757
# Fitted:  19:09:08.109874
# Variance Explained:  0.65648067
# Transformed Model: (150, 40)
# Beginning fit for subject_12_stimulus_12
# Beginning fit:  19:09:08.571100
# Fitted:  19:09:09.451942
# Variance Explained:  0.65416485
# Transformed Model: (150, 40)
# Beginning fit for subject_12_stimulus_14
# Beginning fit:  19:09:09.634427
# Fitted:  19:09:09.713136
# Variance Explained:  1.0000001
# Transformed Model: (25, 25)
# Beginning fit for subject_12_stimulus_15
# Beginning fit:  19:09:09.778309
# Fitted:  19:09:09.858523
# Variance Explained:  1.0
# Transformed Model: (25, 25)
# Beginning fit for subject_12_stimulus_1
# Beginning fit:  19:09:10.546646
# Fitted:  19:09:12.256371
# Variance Explained:  0.3488538
# Transformed Model: (800, 25)
# Beginning fit for subject_12_stimulus_2
# Beginning fit:  19:09:13.329476
# Fitted:  19:09:16.585662
# Variance Explained:  0.44288564
# Transformed Model: (800, 25)
# Beginning fit for subject_12_stimulus_3
# Beginning fit:  19:09:19.400897
# Fitted:  19:09:26.239276
# Variance Explained:  0.3539297
# Transformed Model: (2750, 25)
# Beginning fit for subject_12_stimulus_4
# Beginning fit:  19:09:27.753697
# Fitted:  19:09:29.285269
# Variance Explained:  0.38909632
# Transformed Model: (640, 25)
# Beginning fit for subject_12_stimulus_9
# Beginning fit:  19:09:29.705386
# Fitted:  19:09:30.168119
# Variance Explained:  0.5150132
# Transformed Model: (150, 25)
# Beginning fit for subject_13
# Beginning fit:  19:09:35.008229
# Fitted:  19:09:56.283706
# Variance Explained:  0.2928235380365078
# Transformed Model: (4840, 25)
# Beginning fit for subject_13_stimulus_0
# Beginning fit:  19:10:00.460843
# Fitted:  19:10:02.102209
# Variance Explained:  0.44162637
# Transformed Model: (270, 25)
# Beginning fit for subject_13_stimulus_10
# Beginning fit:  19:10:02.507286
# Fitted:  19:10:03.263296
# Variance Explained:  0.6287831
# Transformed Model: (50, 25)
# Beginning fit for subject_13_stimulus_11
# Beginning fit:  19:10:03.430742
# Fitted:  19:10:03.855370
# Variance Explained:  0.63166314
# Transformed Model: (50, 25)
# Beginning fit for subject_13_stimulus_12
# Beginning fit:  19:10:04.028833
# Fitted:  19:10:04.424383
# Variance Explained:  0.64105934
# Transformed Model: (50, 25)
# Beginning fit for subject_13_stimulus_14
# Beginning fit:  19:10:04.633191
# Fitted:  19:10:05.096922
# Variance Explained:  0.6610888
# Transformed Model: (100, 25)
# Beginning fit for subject_13_stimulus_15
# Beginning fit:  19:10:05.335056
# Fitted:  19:10:05.873990
# Variance Explained:  0.71383566
# Transformed Model: (100, 25)
# Beginning fit for subject_13_stimulus_1
# Beginning fit:  19:10:06.441321
# Fitted:  19:10:08.106750
# Variance Explained:  0.3353082
# Transformed Model: (440, 25)
# Beginning fit for subject_13_stimulus_2
# Beginning fit:  19:10:09.288393
# Fitted:  19:10:12.484392
# Variance Explained:  0.3590077
# Transformed Model: (440, 25)
# Beginning fit for subject_13_stimulus_3
# Beginning fit:  19:10:14.881724
# Fitted:  19:10:21.260185
# Variance Explained:  0.34350383
# Transformed Model: (2090, 25)
# Beginning fit for subject_13_stimulus_4
# Beginning fit:  19:10:23.379721
# Fitted:  19:10:27.916285
# Variance Explained:  0.25559977
# Transformed Model: (1200, 25)
# Beginning fit for subject_13_stimulus_9
# Beginning fit:  19:10:28.781585
# Fitted:  19:10:29.205713
# Variance Explained:  0.6284918
# Transformed Model: (50, 25)
# Beginning fit for subject_14
# Beginning fit:  19:10:33.428932
# Fitted:  19:10:50.742471
# Variance Explained:  0.35559396782534736
# Transformed Model: (3890, 25)
# Beginning fit for subject_14_stimulus_0
# Beginning fit:  19:10:53.959286
# Fitted:  19:10:54.664661
# Variance Explained:  0.6200943
# Transformed Model: (175, 25)
# Beginning fit for subject_14_stimulus_10
# Beginning fit:  19:10:54.863190
# Fitted:  19:10:54.994538
# Variance Explained:  0.93899465
# Transformed Model: (30, 25)
# Beginning fit for subject_14_stimulus_11
# Beginning fit:  19:10:55.111851
# Fitted:  19:10:55.351990
# Variance Explained:  0.90568835
# Transformed Model: (30, 25)
# Beginning fit for subject_14_stimulus_12
# Beginning fit:  19:10:55.522443
# Fitted:  19:10:55.810208
# Variance Explained:  0.90424883
# Transformed Model: (30, 25)
# Beginning fit for subject_14_stimulus_14
# Beginning fit:  19:10:55.982666
# Fitted:  19:10:56.790314
# Variance Explained:  0.8822201
# Transformed Model: (40, 25)
# Beginning fit for subject_14_stimulus_15
# Beginning fit:  19:10:56.984832
# Fitted:  19:10:57.595455
# Variance Explained:  0.9025831
# Transformed Model: (40, 25)
# Beginning fit for subject_14_stimulus_1
# Beginning fit:  19:10:58.298670
# Fitted:  19:11:00.155609
# Variance Explained:  0.29726574
# Transformed Model: (640, 25)
# Beginning fit for subject_14_stimulus_2
# Beginning fit:  19:11:01.202409
# Fitted:  19:11:03.926161
# Variance Explained:  0.22601289
# Transformed Model: (640, 25)
# Beginning fit for subject_14_stimulus_3
# Beginning fit:  19:11:06.664285
# Fitted:  19:11:12.768518
# Variance Explained:  0.38774082
# Transformed Model: (1735, 25)
# Beginning fit for subject_14_stimulus_4
# Beginning fit:  19:11:14.200461
# Fitted:  19:11:15.749078
# Variance Explained:  0.469637
# Transformed Model: (500, 25)
# Beginning fit for subject_14_stimulus_9
# Beginning fit:  19:11:16.088481
# Fitted:  19:11:16.209805
# Variance Explained:  0.90692866
# Transformed Model: (30, 25)
# Beginning fit for subject_15
# Beginning fit:  19:11:20.671089
# Fitted:  19:11:36.855779
# Variance Explained:  0.3141322216347437
# Transformed Model: (4880, 25)
# Beginning fit for subject_15_stimulus_0
# Beginning fit:  19:11:39.696334
# Fitted:  19:11:40.813303
# Variance Explained:  0.3539947
# Transformed Model: (330, 25)
# Beginning fit for subject_15_stimulus_10
# Beginning fit:  19:11:41.344216
# Fitted:  19:11:42.531874
# Variance Explained:  0.61533666
# Transformed Model: (240, 25)
# Beginning fit for subject_15_stimulus_11
# Beginning fit:  19:11:43.032204
# Fitted:  19:11:43.650848
# Variance Explained:  0.38892815
# Transformed Model: (240, 25)
# Beginning fit for subject_15_stimulus_12
# Beginning fit:  19:11:43.960171
# Fitted:  19:11:44.471029
# Variance Explained:  0.36513722
# Transformed Model: (240, 25)
# Beginning fit for subject_15_stimulus_14
# Beginning fit:  19:11:44.639477
# Fitted:  19:11:44.918720
# Variance Explained:  0.7547289
# Transformed Model: (50, 25)
# Beginning fit for subject_15_stimulus_15
# Beginning fit:  19:11:45.026508
# Fitted:  19:11:45.330816
# Variance Explained:  0.76895005
# Transformed Model: (50, 25)
# Beginning fit for subject_15_stimulus_1
# Beginning fit:  19:11:45.921971
# Fitted:  19:11:47.368318
# Variance Explained:  0.20162667
# Transformed Model: (725, 25)
# Beginning fit for subject_15_stimulus_2
# Beginning fit:  19:11:48.499869
# Fitted:  19:11:51.499344
# Variance Explained:  0.19324501
# Transformed Model: (725, 25)
# Beginning fit for subject_15_stimulus_3
# Beginning fit:  19:11:52.860097
# Fitted:  19:11:55.518665
# Variance Explained:  0.39304647
# Transformed Model: (1440, 25)
# Beginning fit for subject_15_stimulus_4
# Beginning fit:  19:11:56.536959
# Fitted:  19:11:58.798973
# Variance Explained:  0.5054746
# Transformed Model: (600, 25)
# Beginning fit for subject_15_stimulus_9
# Beginning fit:  19:11:59.224605
# Fitted:  19:11:59.827208
# Variance Explained:  0.44425845
# Transformed Model: (240, 25)
# Beginning fit for subject_16
# Beginning fit:  19:12:01.529879
# Fitted:  19:12:09.718183
# Variance Explained:  0.3449486138355959
# Transformed Model: (1877, 25)
# Beginning fit for subject_16_stimulus_10
# Beginning fit:  19:12:11.049723
# Fitted:  19:12:11.504433
# Variance Explained:  0.659374
# Transformed Model: (80, 25)
# Beginning fit for subject_16_stimulus_11
# Beginning fit:  19:12:11.675389
# Fitted:  19:12:12.548710
# Variance Explained:  0.5911432
# Transformed Model: (80, 25)
# Beginning fit for subject_16_stimulus_12
# Beginning fit:  19:12:12.812411
# Fitted:  19:12:13.738876
# Variance Explained:  0.57733846
# Transformed Model: (80, 25)
# Beginning fit for subject_16_stimulus_1
# Beginning fit:  19:12:14.250235
# Fitted:  19:12:15.377760
# Variance Explained:  0.33270532
# Transformed Model: (300, 25)
# Beginning fit for subject_16_stimulus_2
# Beginning fit:  19:12:15.839504
# Fitted:  19:12:16.925389
# Variance Explained:  0.31079173
# Transformed Model: (300, 25)
# Beginning fit for subject_16_stimulus_3
# Beginning fit:  19:12:17.506292
# Fitted:  19:12:18.804243
# Variance Explained:  0.34511825
# Transformed Model: (440, 25)
# Beginning fit for subject_16_stimulus_4
# Beginning fit:  19:12:19.646155
# Fitted:  19:12:22.528318
# Variance Explained:  0.38340265
# Transformed Model: (517, 25)
# Beginning fit for subject_16_stimulus_9
# Beginning fit:  19:12:22.875742
# Fitted:  19:12:23.266281
# Variance Explained:  0.57755685
# Transformed Model: (80, 25)
# Beginning fit for subject_17
# Beginning fit:  19:12:29.485488
# Fitted:  19:12:50.690381
# Variance Explained:  0.2134700775755791
# Transformed Model: (5554, 25)
# Beginning fit for subject_17_stimulus_0
# Beginning fit:  19:12:55.954024
# Fitted:  19:12:57.116616
# Variance Explained:  0.3079211
# Transformed Model: (352, 25)
# Beginning fit for subject_17_stimulus_10
# Beginning fit:  19:12:57.483592
# Fitted:  19:12:58.092211
# Variance Explained:  0.53538084
# Transformed Model: (192, 25)
# Beginning fit for subject_17_stimulus_11
# Beginning fit:  19:12:58.512830
# Fitted:  19:12:59.572147
# Variance Explained:  0.39200822
# Transformed Model: (192, 25)
# Beginning fit for subject_17_stimulus_12
# Beginning fit:  19:13:00.034878
# Fitted:  19:13:00.869167
# Variance Explained:  0.3978974
# Transformed Model: (192, 25)
# Beginning fit for subject_17_stimulus_14
# Beginning fit:  19:13:01.097776
# Fitted:  19:13:01.475279
# Variance Explained:  0.7099547
# Transformed Model: (50, 25)
# Beginning fit for subject_17_stimulus_15
# Beginning fit:  19:13:01.606129
# Fitted:  19:13:01.989653
# Variance Explained:  0.7078306
# Transformed Model: (50, 25)
# Beginning fit for subject_17_stimulus_1
# Beginning fit:  19:13:02.766761
# Fitted:  19:13:04.834258
# Variance Explained:  0.19622074
# Transformed Model: (783, 25)
# Beginning fit for subject_17_stimulus_2
# Beginning fit:  19:13:06.175765
# Fitted:  19:13:09.237963
# Variance Explained:  0.21869595
# Transformed Model: (783, 25)
# Beginning fit for subject_17_stimulus_3
# Beginning fit:  19:13:11.217124
# Fitted:  19:13:16.361304
# Variance Explained:  0.26236507
# Transformed Model: (1968, 25)
# Beginning fit for subject_17_stimulus_4
# Beginning fit:  19:13:17.861652
# Fitted:  19:13:19.768221
# Variance Explained:  0.25863954
# Transformed Model: (800, 25)
# Beginning fit for subject_17_stimulus_9
# Beginning fit:  19:13:20.273565
# Fitted:  19:13:20.823528
# Variance Explained:  0.3854451
# Transformed Model: (192, 25)
# Beginning fit for subject_1
# Beginning fit:  19:13:24.397138
# Fitted:  19:13:39.969457
# Variance Explained:  0.3323532224108558
# Transformed Model: (2880, 25)
# Beginning fit for subject_1_stimulus_0
# Beginning fit:  19:13:43.844528
# Fitted:  19:13:47.155358
# Variance Explained:  0.46576652
# Transformed Model: (720, 25)
# Beginning fit for subject_1_stimulus_1
# Beginning fit:  19:13:48.367737
# Fitted:  19:13:50.784163
# Variance Explained:  0.32515714
# Transformed Model: (720, 25)
# Beginning fit for subject_1_stimulus_2
# Beginning fit:  19:13:52.438061
# Fitted:  19:13:55.028019
# Variance Explained:  0.38842878
# Transformed Model: (720, 25)
# Beginning fit for subject_1_stimulus_3
# Beginning fit:  19:13:56.243420
# Fitted:  19:13:58.959157
# Variance Explained:  0.32190582
# Transformed Model: (720, 25)
# Beginning fit for subject_2
# Beginning fit:  19:14:03.873290
# Fitted:  19:14:21.706212
# Variance Explained:  0.22231098493718127
# Transformed Model: (3520, 25)
# Beginning fit for subject_2_stimulus_0
# Beginning fit:  19:14:26.617067
# Fitted:  19:14:30.179047
# Variance Explained:  0.24937408
# Transformed Model: (880, 25)
# Beginning fit for subject_2_stimulus_1
# Beginning fit:  19:14:31.729542
# Fitted:  19:14:34.560575
# Variance Explained:  0.2446628
# Transformed Model: (880, 25)
# Beginning fit for subject_2_stimulus_2
# Beginning fit:  19:14:36.529313
# Fitted:  19:14:39.926344
# Variance Explained:  0.22196332
# Transformed Model: (880, 25)
# Beginning fit for subject_2_stimulus_3
# Beginning fit:  19:14:41.366052
# Fitted:  19:14:44.647277
# Variance Explained:  0.29993802
# Transformed Model: (880, 25)
# Beginning fit for subject_3
# Beginning fit:  19:14:48.487468
# Fitted:  19:15:01.713209
# Variance Explained:  0.18864652340321272
# Transformed Model: (2560, 25)
# Beginning fit for subject_3_stimulus_0
# Beginning fit:  19:15:04.795255
# Fitted:  19:15:07.966689
# Variance Explained:  0.25642243
# Transformed Model: (640, 25)
# Beginning fit for subject_3_stimulus_1
# Beginning fit:  19:15:09.122402
# Fitted:  19:15:11.223489
# Variance Explained:  0.23261718
# Transformed Model: (640, 25)
# Beginning fit for subject_3_stimulus_2
# Beginning fit:  19:15:12.337094
# Fitted:  19:15:16.119736
# Variance Explained:  0.22560145
# Transformed Model: (640, 25)
# Beginning fit for subject_3_stimulus_3
# Beginning fit:  19:15:17.243938
# Fitted:  19:15:19.398665
# Variance Explained:  0.25046027
# Transformed Model: (640, 25)
# Beginning fit for subject_4
# Beginning fit:  19:15:23.849007
# Fitted:  19:15:40.106118
# Variance Explained:  0.15820167067879776
# Transformed Model: (2880, 25)
# Beginning fit for subject_4_stimulus_0
# Beginning fit:  19:15:43.847635
# Fitted:  19:15:47.600114
# Variance Explained:  0.19453184
# Transformed Model: (720, 25)
# Beginning fit for subject_4_stimulus_1
# Beginning fit:  19:15:48.897446
# Fitted:  19:15:51.440776
# Variance Explained:  0.17879312
# Transformed Model: (720, 25)
# Beginning fit for subject_4_stimulus_2
# Beginning fit:  19:15:52.913492
# Fitted:  19:15:56.381714
# Variance Explained:  0.18280791
# Transformed Model: (720, 25)
# Beginning fit for subject_4_stimulus_3
# Beginning fit:  19:15:57.675973
# Fitted:  19:16:00.379716
# Variance Explained:  0.1988757
# Transformed Model: (720, 25)
# Beginning fit for subject_5
# Beginning fit:  19:16:05.233019
# Fitted:  19:16:22.533023
# Variance Explained:  0.2362631661682274
# Transformed Model: (2880, 25)
# Beginning fit for subject_5_stimulus_0
# Beginning fit:  19:16:27.749900
# Fitted:  19:16:31.111339
# Variance Explained:  0.31197846
# Transformed Model: (720, 25)
# Beginning fit for subject_5_stimulus_1
# Beginning fit:  19:16:32.791839
# Fitted:  19:16:35.448912
# Variance Explained:  0.25583073
# Transformed Model: (720, 25)
# Beginning fit for subject_5_stimulus_2
# Beginning fit:  19:16:37.048029
# Fitted:  19:16:41.500870
# Variance Explained:  0.2643364
# Transformed Model: (720, 25)
# Beginning fit for subject_5_stimulus_3
# Beginning fit:  19:16:42.908332
# Fitted:  19:16:46.858338
# Variance Explained:  0.300227
# Transformed Model: (720, 25)
# Beginning fit for subject_6
# Beginning fit:  19:16:52.405972
# Fitted:  19:17:14.691064
# Variance Explained:  0.20856913778450295
# Transformed Model: (3780, 25)
# Beginning fit for subject_6_stimulus_1
# Beginning fit:  19:17:21.003274
# Fitted:  19:17:25.004413
# Variance Explained:  0.24382922
# Transformed Model: (1080, 25)
# Beginning fit for subject_6_stimulus_2
# Beginning fit:  19:17:27.242607
# Fitted:  19:17:30.809592
# Variance Explained:  0.2533292
# Transformed Model: (1080, 25)
# Beginning fit for subject_6_stimulus_3
# Beginning fit:  19:17:34.222502
# Fitted:  19:17:41.580067
# Variance Explained:  0.18824714
# Transformed Model: (1620, 25)
# Beginning fit for subject_7
# Beginning fit:  19:17:45.208406
# Fitted:  19:17:55.106228
# Variance Explained:  0.3562530268620451
# Transformed Model: (1650, 25)
# Beginning fit for subject_7_stimulus_1
# Beginning fit:  19:17:58.615402
# Fitted:  19:18:00.786826
# Variance Explained:  0.39580294
# Transformed Model: (550, 25)
# Beginning fit for subject_7_stimulus_2
# Beginning fit:  19:18:01.828894
# Fitted:  19:18:05.423453
# Variance Explained:  0.39639995
# Transformed Model: (550, 25)
# Beginning fit for subject_7_stimulus_3
# Beginning fit:  19:18:06.497072
# Fitted:  19:18:08.653807
# Variance Explained:  0.3820444
# Transformed Model: (550, 25)
