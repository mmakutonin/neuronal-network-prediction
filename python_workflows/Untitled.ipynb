# %%
import numpy as np
import pandas as pd
from util_functions import list_subjects, load_file, pickle_file, starting_run, finished_run

# %%
data_raw_pickled_df = load_file('data_meta_pickled/data_raw_pickled_df.pickle')

# %%
data_raw_pickled_df
# Out:
#                  subject stimulus  \
# subject_01    subject_01     None
# subject_02    subject_02     None
# subject_03    subject_03     None
# subject_04    subject_04     None
# subject_05    subject_05     None
# ...                  ...      ...
# subject_r219  subject_r2       19
# subject_r220  subject_r2       20
# subject_r221  subject_r2       21
# subject_r222  subject_r2       22
# subject_r223  subject_r2       23
#
#                                                        rel_path  \
# subject_01         data_raw_pickled/subject_01_CellRespZ.pickle
# subject_02         data_raw_pickled/subject_02_CellRespZ.pickle
# subject_03         data_raw_pickled/subject_03_CellRespZ.pickle
# subject_04         data_raw_pickled/subject_04_CellRespZ.pickle
# subject_05         data_raw_pickled/subject_05_CellRespZ.pickle
# ...                                                         ...
# subject_r219  data_raw_pickled/subject_r2_stimulus_19_CellRe...
# subject_r220  data_raw_pickled/subject_r2_stimulus_20_CellRe...
# subject_r221  data_raw_pickled/subject_r2_stimulus_21_CellRe...
# subject_r222  data_raw_pickled/subject_r2_stimulus_22_CellRe...
# subject_r223  data_raw_pickled/subject_r2_stimulus_23_CellRe...
#
#              timepoints_count  \
# subject_01               2880
# subject_02               3520
# subject_03               2560
# subject_04               2880
# subject_05               2880
# ...                       ...
# subject_r219              198
# subject_r220               29
# subject_r221               21
# subject_r222              309
# subject_r223               63
#
#                                                      timepoints
# subject_01                                                 None
# subject_02                                                 None
# subject_03                                                 None
# subject_04                                                 None
# subject_05                                                 None
# ...                                                         ...
# subject_r219  Int64Index([   0,    1,    2,    3,    4,    5...
# subject_r220  Int64Index([1717, 1718, 1719, 1720, 1721, 1722...
# subject_r221  Int64Index([1163, 1164, 1165, 1166, 1167, 1168...
# subject_r222  Int64Index([ 476,  477,  478,  479,  480,  481...
# subject_r223  Int64Index([2867, 2868, 2869, 2870, 2871, 2872...
#
# [181 rows x 5 columns]

# %%
load_file('data_raw_pickled/subject_01_CellRespZ.pickle').shape
# Out:
# (2880, 83205)
