# %%
import os
import pandas as pd
import numpy as np
import scipy.io as scio
import h5py
import pickle
from datetime import datetime

# %%
data_dir = '../data/'
input_data_dir = data_dir + 'data_raw_from_paper/'
output_data_dir = data_dir + 'data_raw_pickled/'

# %%
def save_mat_data(path, subject):
    mat = scio.loadmat(path)
    mat_dict = {
        "periods": mat['data'][0][0][0],
        "timelists_names": mat['data'][0][0][1],
        "stimulus_key_raw": mat['data'][0][0][2],
        "cell_XYZ": mat['data'][0][0][3],
        "anat_stack": mat['data'][0][0][4],
        "frame_per_sec": mat['data'][0][0][5],
        "behavior_raw": mat['data'][0][0][6],
        "num_cells": mat['data'][0][0][7],
        "cell_XYZ_norm": mat['data'][0][0][8],
        "IX_inval_anat": mat['data'][0][0][9],
        "anat_yx": mat['data'][0][0][10],
        "anat_yz": mat['data'][0][0][11],
        "anat_xz": mat['data'][0][0][12],
        "timelists": mat['data'][0][0][13],
        "stim_full": mat['data'][0][0][14],
        "stim_avr": mat['data'][0][0][15],
        "behavior_full": mat['data'][0][0][16],
        "behavior_avr": mat['data'][0][0][17],
#         "behavior_full_motor": mat['data'][0][0][18],
#         "behavior_avr_motor": mat['data'][0][0][19],
#         "eye_full_motorseed": mat['data'][0][0][20],
#         "eye_avr_motorseed": mat['data'][0][0][21],
#         "eye_full": mat['data'][0][0][22],
#         "eye_avr": mat['data'][0][0][23]
    }
#     for key in mat_dict:
#         print(key, mat_dict[key].shape)
    with open(output_data_dir + subject + '_mat_dict.pickle', 'wb') as pickle_file:
        pickle.dump(mat_dict, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def save_h5_data(path, subject):
    f = h5py.File(path, 'r')
    for key in f.keys():
        print('Saving ', key, ' in .h5 file: ', datetime.now().time())
        with open(output_data_dir + subject + '_' + key + '.pickle', 'wb') as pickle_file:
            pickle.dump(pd.DataFrame(np.array(f[key])), pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for subject in os.listdir(path = input_data_dir):
    print('Starting to save ', subject, ': ', datetime.now().time())
    save_mat_data(input_data_dir + subject + '/data_full.mat', subject)
    print('Finished saving .mat, starting .h5 files: ', datetime.now().time())
    save_h5_data(input_data_dir + subject + '/TimeSeries.h5', subject)
    print('Finished saving all files: ', datetime.now().time())
# Out:
# Starting to save  subject_1 :  15:16:04.176767
# Finished saving .mat, starting .h5 files:  15:16:06.253687
# Saving  CellResp  in .h5 file:  15:16:06.277655
# Saving  CellRespAvr  in .h5 file:  15:16:19.321049
# Saving  CellRespAvrZ  in .h5 file:  15:16:21.281983
# Saving  CellRespZ  in .h5 file:  15:16:23.444572
# Saving  absIX  in .h5 file:  15:16:36.721542
# Finished saving all files:  15:16:36.724532
# Starting to save  subject_10 :  15:16:36.724532
# Finished saving .mat, starting .h5 files:  15:16:38.731742
# Saving  CellResp  in .h5 file:  15:16:38.756673
# Saving  CellRespAvr  in .h5 file:  15:17:01.729151
# Saving  CellRespAvrZ  in .h5 file:  15:17:07.533563
# Saving  CellRespZ  in .h5 file:  15:17:15.133340
# Saving  absIX  in .h5 file:  15:17:40.917729
# Finished saving all files:  15:17:40.922778
# Starting to save  subject_12 :  15:17:40.922778
# Finished saving .mat, starting .h5 files:  15:17:43.438589
# Saving  CellResp  in .h5 file:  15:17:43.532975
# Saving  CellRespAvr  in .h5 file:  15:18:15.676458
# Saving  CellRespAvrZ  in .h5 file:  15:18:27.668867
# Saving  CellRespZ  in .h5 file:  15:18:38.733225
# Saving  absIX  in .h5 file:  15:19:26.522027
# Finished saving all files:  15:19:27.102760
# Starting to save  subject_13 :  15:19:27.105754
# Finished saving .mat, starting .h5 files:  15:19:29.115361
# Saving  CellResp  in .h5 file:  15:19:29.350539
# Saving  CellRespAvr  in .h5 file:  15:20:06.726191
# Saving  CellRespAvrZ  in .h5 file:  15:20:15.819922
# Saving  CellRespZ  in .h5 file:  15:20:23.495530
# Saving  absIX  in .h5 file:  15:21:01.025069
# Finished saving all files:  15:21:01.045016
# Starting to save  subject_14 :  15:21:01.046025
# Finished saving .mat, starting .h5 files:  15:21:05.003722
# Saving  CellResp  in .h5 file:  15:21:05.098437
# Saving  CellRespAvr  in .h5 file:  15:21:21.399330
# Saving  CellRespAvrZ  in .h5 file:  15:21:24.999477
# Saving  CellRespZ  in .h5 file:  15:21:28.531978
# Saving  absIX  in .h5 file:  15:21:44.281681
# Finished saving all files:  15:21:44.286667
# Starting to save  subject_15 :  15:21:44.286667
# Finished saving .mat, starting .h5 files:  15:21:46.562996
# Saving  CellResp  in .h5 file:  15:21:46.610870
# Saving  CellRespAvr  in .h5 file:  15:22:02.106705
# Saving  CellRespAvrZ  in .h5 file:  15:22:03.600662
# Saving  CellRespZ  in .h5 file:  15:22:05.185115
# Saving  absIX  in .h5 file:  15:22:20.059878
# Finished saving all files:  15:22:20.214466
# Starting to save  subject_16 :  15:22:20.214466
# Finished saving .mat, starting .h5 files:  15:22:23.148680
# Saving  CellResp  in .h5 file:  15:22:23.234114
# Saving  CellRespAvr  in .h5 file:  15:22:30.724080
# Saving  CellRespAvrZ  in .h5 file:  15:22:33.183823
# Saving  CellRespZ  in .h5 file:  15:22:35.470980
# Saving  absIX  in .h5 file:  15:22:42.621841
# Finished saving all files:  15:22:42.625799
# Starting to save  subject_17 :  15:22:42.625799
# Finished saving .mat, starting .h5 files:  15:22:44.742504
# Saving  CellResp  in .h5 file:  15:22:44.766441
# Saving  CellRespAvr  in .h5 file:  15:23:04.855666
# Saving  CellRespAvrZ  in .h5 file:  15:23:07.168188
# Saving  CellRespZ  in .h5 file:  15:23:10.455454
# Saving  absIX  in .h5 file:  15:23:29.894221
# Finished saving all files:  15:23:29.900206
# Starting to save  subject_2 :  15:23:29.900206
# Finished saving .mat, starting .h5 files:  15:23:31.869938
# Saving  CellResp  in .h5 file:  15:23:31.937786
# Saving  CellRespAvr  in .h5 file:  15:23:49.443637
# Saving  CellRespAvrZ  in .h5 file:  15:23:50.256736
# Saving  CellRespZ  in .h5 file:  15:23:50.986859
# Saving  absIX  in .h5 file:  15:24:08.594983
# Finished saving all files:  15:24:08.598972
# Starting to save  subject_3 :  15:24:08.598972
# Finished saving .mat, starting .h5 files:  15:24:11.288850
# Saving  CellResp  in .h5 file:  15:24:11.428895
# Saving  CellRespAvr  in .h5 file:  15:24:32.670923
# Saving  CellRespAvrZ  in .h5 file:  15:24:35.042916
# Saving  CellRespZ  in .h5 file:  15:24:36.228974
# Saving  absIX  in .h5 file:  15:24:51.744289
# Finished saving all files:  15:24:51.749277
# Starting to save  subject_4 :  15:24:51.749277
# Finished saving .mat, starting .h5 files:  15:24:54.201413
# Saving  CellResp  in .h5 file:  15:24:54.262538
# Saving  CellRespAvr  in .h5 file:  15:25:09.845381
# Saving  CellRespAvrZ  in .h5 file:  15:25:11.560221
# Saving  CellRespZ  in .h5 file:  15:25:13.436354
# Saving  absIX  in .h5 file:  15:25:39.274597
# Finished saving all files:  15:25:39.278587
# Starting to save  subject_5 :  15:25:39.278587
# Finished saving .mat, starting .h5 files:  15:25:41.395015
# Saving  CellResp  in .h5 file:  15:25:41.499353
# Saving  CellRespAvr  in .h5 file:  15:25:57.064376
# Saving  CellRespAvrZ  in .h5 file:  15:25:59.861941
# Saving  CellRespZ  in .h5 file:  15:26:02.675034
# Saving  absIX  in .h5 file:  15:26:20.937948
# Finished saving all files:  15:26:20.941938
# Starting to save  subject_6 :  15:26:20.941938
# Finished saving .mat, starting .h5 files:  15:26:23.413087
# Saving  CellResp  in .h5 file:  15:26:23.626848
# Saving  CellRespAvr  in .h5 file:  15:26:45.613448
# Saving  CellRespAvrZ  in .h5 file:  15:26:47.578472
# Saving  CellRespZ  in .h5 file:  15:26:48.982048
# Saving  absIX  in .h5 file:  15:27:18.570459
# Finished saving all files:  15:27:18.576444
# Starting to save  subject_7 :  15:27:18.576444
# Finished saving .mat, starting .h5 files:  15:27:22.001863
# Saving  CellResp  in .h5 file:  15:27:22.059910
# Saving  CellRespAvr  in .h5 file:  15:27:33.909732
# Saving  CellRespAvrZ  in .h5 file:  15:27:35.386175
# Saving  CellRespZ  in .h5 file:  15:27:36.539899
# Saving  absIX  in .h5 file:  15:27:48.544269
# Finished saving all files:  15:27:48.550253
